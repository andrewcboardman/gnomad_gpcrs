# %%
import pandas as pd

# %%
lof_variants = pd.read_csv('../data/gnomad_v2.1.1_gpcr_variants_high.csv',index_col=0)
lof_variants
# Out:
#         CHROM        POS                ID  REF ALT      AN  AC  nhomalt  \
# 163         1  159174749   ['rs756754694']    A   G  251376   2        0
# 169         1  159174749   ['rs756754694']    A   G  251376   2        0
# 181         1  159174755   ['rs768744460']  AAC   A  251342   1        0
# 187         1  159174755   ['rs768744460']  AAC   A  251342   1        0
# 226         1  159174770   ['rs748490259']    G   T  251042   2        0
# ...       ...        ...               ...  ...  ..     ...  ..      ...
# 1680625     3   46063193  ['rs1245227110']    G   T  251380   0        0
# 1680628     3   46063193  ['rs1245227110']    G   T  251380   0        0
# 1680797     3   46063398   ['rs751305976']   TA   T  250010   0        0
# 1680798     3   46063398   ['rs751305976']   TA   T  250010   0        0
# 1680800     3   46063398   ['rs751305976']   TA   T  250010   0        0
#
#                   Consequence Impact             Gene EXON INTRON protein_pos  \
# ...

# %%
homozygous = lof_variants[lof_variants['nhomalt']>0][['HGNC symbol','protein_pos','amino_acids','nhomalt']].drop_duplicates()

# %%
homozygous
# Out:
#         HGNC symbol protein_pos amino_acids  nhomalt
# 6349          ACKR2         113         G/X        1
# 9661          ACKR2     333-335       WHL/X        1
# 17523         ACKR4         155         W/*        1
# 27739        ADGRA1          80         E/X        3
# 27968        ADGRA1         216         L/X        2
# ...             ...         ...         ...      ...
# 1635084      TAS2R8         245        F/FX       38
# 1635771      TAS2R8          16         E/*        7
# 1641291       TPRA1         245         R/*        6
# 1655477       UTS2R         242         Q/*        1
# 1679865        XCR1         292        V/GX        1
#
# [250 rows x 4 columns]

# %%
pd.read_csv('../../receptors/GPCRdb_gpcr_classes_070121.csv')
# Out:
#     HGNC Symbol      Uniprot       Ensembl ID Class         Ligand type  \
# 0         HCAR1  HCAR1_HUMAN  ENSG00000196917     A  Alicarboxylic acid
# 1         HCAR2  HCAR2_HUMAN  ENSG00000182782     A  Alicarboxylic acid
# 2         HCAR3  HCAR3_HUMAN  ENSG00000255398     A  Alicarboxylic acid
# 3         OXGR1  OXGR1_HUMAN  ENSG00000165621     A  Alicarboxylic acid
# 4        SUCNR1  SUCR1_HUMAN  ENSG00000198829     A  Alicarboxylic acid
# ..          ...          ...              ...   ...                 ...
# 392      TAS2R4  TA2R4_HUMAN  ENSG00000127364     T             Sensory
# 393      TAS2R5  TA2R5_HUMAN  ENSG00000127366     T             Sensory
# 394      TAS2R7  TA2R7_HUMAN  ENSG00000121377     T             Sensory
# 395      TAS2R8  TA2R8_HUMAN  ENSG00000121314     T             Sensory
# 396      TAS2R9  TA2R9_HUMAN  ENSG00000121381     T             Sensory
#
#                      Family Gs     Gi/o      Gq/11 G12/13
# ...
