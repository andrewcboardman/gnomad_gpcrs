# %%
import pandas as pd
import numpy as np

# %%
synthetic_coding_variants = pd.read_csv('../data/GPCR_annotated_synthetic_coding_variants.txt', sep='\t')
synthetic_coding_variants
# Out:
#         #Uploaded_variation     Location Allele             Gene  \
# 0             ACKR1.162.C>A  1:159173258      A  ENSG00000213088
# 1             ACKR1.162.C>G  1:159173258      G  ENSG00000213088
# 2             ACKR1.162.C>T  1:159173258      T  ENSG00000213088
# 3             ACKR1.163.A>C  1:159173259      C  ENSG00000213088
# 4             ACKR1.163.A>G  1:159173259      G  ENSG00000213088
# ...                     ...          ...    ...              ...
# 1156105      VIPR2.2623.G>C  7:158823488      C  ENSG00000106018
# 1156106      VIPR2.2623.G>C  7:158823488      C  ENSG00000106018
# 1156107      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
# 1156108      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
# 1156109      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
#
#                  Feature Feature_type  \
# 0        ENST00000537147   Transcript
# 1        ENST00000537147   Transcript
# 2        ENST00000537147   Transcript
# ...

# %%
extra = synthetic_coding_variants['Extra'].str.split(pat=';',expand=True,n=2)

# %%
synthetic_coding_variants[['Impact','Strand','Extra']] = extra

# %%
synthetic_coding_variants[['Symbol','Nucleotide position','ref>alt']] = synthetic_coding_variants['#Uploaded_variation'].str.split(pat='.',expand=True,n=2)

# %%
synthetic_coding_variants
# Out:
#         #Uploaded_variation     Location Allele             Gene  \
# 0             ACKR1.162.C>A  1:159173258      A  ENSG00000213088
# 1             ACKR1.162.C>G  1:159173258      G  ENSG00000213088
# 2             ACKR1.162.C>T  1:159173258      T  ENSG00000213088
# 3             ACKR1.163.A>C  1:159173259      C  ENSG00000213088
# 4             ACKR1.163.A>G  1:159173259      G  ENSG00000213088
# ...                     ...          ...    ...              ...
# 1156105      VIPR2.2623.G>C  7:158823488      C  ENSG00000106018
# 1156106      VIPR2.2623.G>C  7:158823488      C  ENSG00000106018
# 1156107      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
# 1156108      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
# 1156109      VIPR2.2623.G>T  7:158823488      T  ENSG00000106018
#
#                  Feature Feature_type  \
# 0        ENST00000537147   Transcript
# 1        ENST00000537147   Transcript
# 2        ENST00000537147   Transcript
# ...
