# %%
import pandas as pd

# %%
constraint_by_gene_raw = pd.read_csv('data/gnomad_standard/constraint_final.csv.gz', compression='gzip', index_col=0)
constraint_by_gene_raw
# Out:
#             gene       transcript  canonical  obs        exp        oe  \
# 0     AC005493.1  ENST00000399077       True    4   1.638632  2.441061
# 1     AC018630.1  ENST00000601123       True    0   0.000000       NaN
# 2     AC073342.1  ENST00000595842       True    2   1.214531  1.646726
# 3     AC078925.1  ENST00000601092       True    0   0.000000       NaN
# 4     AC109583.1  ENST00000593391       True    0   0.000000       NaN
# ...          ...              ...        ...  ...        ...       ...
# 1368       WDR64  ENST00000437684      False   27  26.548059  1.017024
# 1369       WDR64  ENST00000468967      False   27  26.548059  1.017024
# 1370        XCR1  ENST00000309285       True   89  95.588635  0.931073
# 1371        XCR1  ENST00000395946      False    8   8.560461  0.934529
# 1372        XCR1  ENST00000542109      False   89  95.588635  0.931073
#
#          adj_mu        raw_mu  poss       metric
# 0      1.659547  1.557809e-07     9  lof_classic
# 1      1.636904  0.000000e+00    28  lof_classic
# 2      1.214531  5.117263e-08    18  lof_classic
# 3     10.500029  0.000000e+00    67  lof_classic
# 4      1.445804  0.000000e+00    19  lof_classic
# ...         ...           ...   ...          ...
# 1368  28.844352  1.327099e-06   281          syn
# 1369  28.844352  1.327099e-06   281          syn
# 1370  95.793930  6.051429e-06   724          syn
# 1371   8.560461  5.416641e-07    68          syn
# 1372  95.793930  6.051429e-06   724          syn
#
# [10668 rows x 10 columns]

# %%
gpcr_genes = pd.read_csv('data/Ensembl_Grch37_gpcr_genome_locations.csv')
gpcr_genes
gpcr_genes = gpcr_genes[['HGNC symbol','HGNC name','Grch37 symbol']]
gpcr_genes.columns = ['symbol','gene_name_long','gene']

# %%
gpcr_constraint = gpcr_genes.merge(constraint_by_gene_raw, on='gene',how='left')
gpcr_constraint = gpcr_constraint[gpcr_constraint.canonical].drop(columns = ['canonical'])
gpcr_constraint = gpcr_constraint[gpcr_constraint.metric.isin(('lof_hc','mis_pphen'))]
gpcr_constraint = pd.pivot(gpcr_constraint,index=['symbol','gene_name_long','gene','transcript'], columns = 'metric', values=['obs','oe'])
.to_csv('data/gpcr_constraint_wide.csv')
